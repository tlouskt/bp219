# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.cluster import AgglomerativeClustering, MeanShift, DBSCAN
from sklearn.neighbors import kneighbors_graph
import umap

# %%
dfProt = pd.read_csv(
    os.getcwd() + '/Ecoli_MS_NormTotal_Fusion_160519_70_77_Proteins.txt',
    sep='\t'
)
print(dfProt.shape)

dfRNA = pd.read_csv(
    os.getcwd() + '/GSE92601_Escherichia_coli.Gene.rpkm.txt',
    index_col='Symbol', na_values='-', sep='\t'
)
print(dfRNA.shape)
# Out:
# (2243, 1)
# (4205, 37)

# %%
dfRNA
# Out:
#        GeneID  Length  ORF1_1_mapped_reads(7655775)  \
# Symbol
# plaP    b2014    1359                        6788.0
# yniB    b1726     537                         528.0
# wzc     b2060    2163                          28.0
# feoC    b3410     237                         117.0
# sgcR    b4300     783                          97.0
# ...       ...     ...                           ...
# gltX    b2400    1416                        6058.0
# dmsC    b0896     864                         182.0
# yciE    b1257     507                         366.0
# pgpC    b2560     636                         461.0
# hyfJ    b2490     414                          29.0
#
#         ORF1_1_IPTG_mapped_reads(7178582)  ORF1_2_mapped_reads(7706927)  \
# Symbol
# plaP                               3977.0                        7207.0
# yniB                                408.0                         481.0
# wzc                                  47.0                          20.0
# ...
