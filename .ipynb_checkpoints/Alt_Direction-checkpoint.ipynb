# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.cluster import AgglomerativeClustering, MeanShift, DBSCAN
from sklearn.neighbors import kneighbors_graph
import umap

# %%
def get_data():
    # This method reads in the Heat Kill vs Normal Data in from your working directory
    heat_kill_data=pd.read_csv("E-TABM-734-A-AFFY-44-query-results.tsv",sep='\t')
    columns = heat_kill_data.columns
    return heat_kill_data, columns

# %%
def get_significant(data, header, cutoff):
    is_sig = data[header <= cutoff]
    sig_data = data
    return

# %%
def main():
    heat_kill_data, columns = get_data() # Read in and capture the data as well as a list of column headers
    sig_data = get_significant(heat_kill_data, heat_kill_data[columns[4]], .05)

# %%
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [106], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In [104], line 3, in main()
#       1 def main():
#       2     heat_kill_data, columns = get_data() # Read in and capture the data as well as a list of column headers
# ----> 3     sig_data = get_significant(heat_kill_data, heat_kill_data[columns[4]], .05)
#       4     print(len(sig_data[columns[0]]))
#
# Cell In [105], line 3, in get_significant(data, header, cutoff)
#       1 def get_significant(data, header, cutoff):
#       2     is_sig = data[header <= cutoff]
# ----> 3     sig_data = data[is_sig]
#       4     return sig_data
#
# File /opt/anaconda3/envs/BP219/lib/python3.10/site-packages/pandas/core/frame.py:3492, in DataFrame.__getitem__(self, key)
#    3490 # Do we have a (boolean) DataFrame?
#    3491 if isinstance(key, DataFrame):
# -> 3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
#
# File /opt/anaconda3/envs/BP219/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/BP219/lib/python3.10/site-packages/pandas/core/frame.py:10961, in DataFrame.where(self, cond, other, inplace, axis, level, errors, try_cast)
#   10948 @deprecate_nonkeyword_arguments(
#   10949     version=None, allowed_args=["self", "cond", "other"]
#   10950 )
#    (...)
#   10959     try_cast=lib.no_default,
#   10960 ):
# > 10961     return super().where(cond, other, inplace, axis, level, errors, try_cast)
#
# File /opt/anaconda3/envs/BP219/lib/python3.10/site-packages/pandas/core/generic.py:9310, in NDFrame.where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9302 if try_cast is not lib.no_default:
#    9303     warnings.warn(
#    9304         "try_cast keyword is deprecated and will be removed in a "
#    9305         "future version.",
#    9306         FutureWarning,
#    9307         stacklevel=find_stack_level(),
#    9308     )
# -> 9310 return self._where(cond, other, inplace, axis, level, errors=errors)
#
# File /opt/anaconda3/envs/BP219/lib/python3.10/site-packages/pandas/core/generic.py:9071, in NDFrame._where(self, cond, other, inplace, axis, level, errors)
#    9069         for dt in cond.dtypes:
#    9070             if not is_bool_dtype(dt):
# -> 9071                 raise ValueError(msg.format(dtype=dt))
#    9072 else:
#    9073     # GH#21947 we have an empty DataFrame/Series, could be object-dtype
#    9074     cond = cond.astype(bool)
#
# ValueError: Boolean array expected for the condition, not object

# %%
heat_kill_data
# Out:
#                Gene ID        Gene Name Design Element  \
# 0      ENSG00000000003           TSPAN6    209109_s_at
# 1      ENSG00000000005             TNMD      220065_at
# 2      ENSG00000000419             DPM1      202673_at
# 3      ENSG00000000457            SCYL3       41329_at
# 4      ENSG00000000460         C1orf112    220840_s_at
# ...                ...              ...            ...
# 20786  ENSG00000288611           NPBWR1      231752_at
# 20787  ENSG00000288642             CDR1      207276_at
# 20788  ENSG00000288649           ACTL10      232619_at
# 20789  ENSG00000288658  ENSG00000288658      238727_at
# 20790  ENSG00000288701           PRRC2B    212068_s_at
#
#        'heat-killed Escherichia coli' vs 'none' in 'normal'.foldChange  \
# 0                                                    0.2
# 1                                                    0.2
# 2                                                    0.3
# 3                                                    1.0
# 4                                                   -0.8
# ...                                                  ...
# 20786                                                0.3
# 20787                                                0.4
# 20788                                               -0.3
# 20789                                                4.6
# 20790                                               -1.3
#
#        'heat-killed Escherichia coli' vs 'none' in 'normal'.pValue  \
# 0                                               0.545176
# 1                                               0.278216
# 2                                               0.050474
# 3                                               0.000730
# 4                                               0.002882
# ...                                                  ...
# 20786                                           0.134510
# 20787                                           0.044863
# 20788                                           0.051159
# 20789                                           0.000002
# 20790                                           0.000007
#
#        'heat-killed Escherichia coli' vs 'none' in 'normal'.tStat  \
# 0                                               0.838607
# 1                                               1.448372
# 2                                               2.637514
# 3                                               5.463637
# 4                                              -4.481124
# ...                                                  ...
# 20786                                           1.986653
# 20787                                           2.714911
# 20788                                          -2.629198
# 20789                                          11.403586
# 20790                                          -9.942291
#
#        'heat-killed Escherichia coli' vs 'none' in 'ulcerative colitis'.foldChange  \
# 0                                                    NaN
# 1                                                    0.1
# 2                                                    0.2
# 3                                                    1.1
# 4                                                   -0.9
# ...                                                  ...
# 20786                                                0.6
# 20787                                                0.5
# 20788                                                NaN
# 20789                                                3.5
# 20790                                               -1.0
#
#        'heat-killed Escherichia coli' vs 'none' in 'ulcerative colitis'.pValue  \
# 0                                                    NaN
# 1                                           1.557884e-01
# 2                                           1.664221e-03
# 3                                           2.490000e-10
# 4                                           5.580000e-09
# ...                                                  ...
# 20786                                       7.740000e-07
# 20787                                       1.460000e-04
# 20788                                                NaN
# 20789                                       4.550000e-21
# 20790                                       2.550000e-13
#
#        'heat-killed Escherichia coli' vs 'none' in 'ulcerative colitis'.tStat  \
# 0                                                    NaN
# 1                                               1.584570
# 2                                               3.641355
# 3                                               9.057902
# 4                                              -7.957607
# ...                                                  ...
# 20786                                           6.292488
# 20787                                           4.524714
# 20788                                                NaN
# 20789                                          21.606653
# 20790                                         -11.744377
#
#        'ulcerative colitis' vs 'normal' in 'heat-killed Escherichia coli'.foldChange  \
# 0                                                    0.1
# 1                                                   -0.1
# 2                                                   -0.1
# 3                                                    0.1
# 4                                                    0.1
# ...                                                  ...
# 20786                                                NaN
# 20787                                               -0.1
# 20788                                                0.1
# 20789                                               -0.2
# 20790                                                0.3
#
#        'ulcerative colitis' vs 'normal' in 'heat-killed Escherichia coli'.pValue  \
# 0                                               0.998683
# 1                                               0.998683
# 2                                               0.998683
# 3                                               0.998683
# 4                                               0.998683
# ...                                                  ...
# 20786                                                NaN
# 20787                                           0.998683
# 20788                                           0.998683
# 20789                                           0.998683
# 20790                                           0.998683
#
#        'ulcerative colitis' vs 'normal' in 'heat-killed Escherichia coli'.tStat  \
# 0                                               0.372320
# 1                                              -0.836933
# 2                                              -1.074565
# 3                                               0.526737
# 4                                               0.416489
# ...                                                  ...
# 20786                                                NaN
# 20787                                          -0.515334
# 20788                                           1.259376
# 20789                                          -0.937727
# 20790                                           1.835726
#
#        'ulcerative colitis' vs 'normal' in 'none'.foldChange  \
# 0                                                    0.4
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20786                                                NaN
# 20787                                                NaN
# 20788                                                NaN
# 20789                                                0.8
# 20790                                                NaN
#
#        'ulcerative colitis' vs 'normal' in 'none'.pValue  \
# 0                                               0.686800
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20786                                                NaN
# 20787                                                NaN
# 20788                                                NaN
# 20789                                           0.269333
# 20790                                                NaN
#
#        'ulcerative colitis' vs 'normal' in 'none'.tStat
# 0                                              1.437008
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 20786                                               NaN
# 20787                                               NaN
# 20788                                               NaN
# 20789                                          2.849931
# 20790                                               NaN
#
# [20791 rows x 15 columns]
